# %% [markdown]
# <a href="https://colab.research.google.com/github/CintiaGuimaraess/Codigos/blob/main/Atividade_de_LPC_22_03_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ETE PORTO DIGITAL
# Aluna: Cíntia Maria de Carvalho Guimarães
# 1° B(1)
# Atividade de LPC
# Professor: Cloves Rocha
# Disciplina: LPC

#1. Faça um CÓDIGO que mostre a mensagem "Olá ETE PORTO DIGITAL!" na tela.

print("Olá ETE PORTO DIGITAL!")




#2. Faça um CÓDIGO que peça um número e então mostre a mensagem O número informado foi [número].

Número = float(input('Digite um número: \n'))

print(f'O número informado foi {Número}')




#3. Faça um CÓDIGO que peça dois números e imprima a soma.

Número1 = float(input('Coloque um número: \n'))
Número2 = float(input('Coloque outro número: \n'))

print(f'A soma dos dois números é {Número1+Número2}')




#4. Faça um CÓDIGO que peça as 4 notas bimestrais e mostre a média final.

Nota1 = float(input('Digite a sua nota do primeiro bimestre: \n'))
Nota2 = float(input('Digite a sua nota do segundo bimestre: \n'))
Nota3 = float(input('Digite a sua nota do terceiro bimestre: \n'))
Nota4 = float(input('Digite a sua nota do quarto bimestre: \n'))

Média = (Nota1 + Nota2 + Nota3 + Nota4)/4

print(f'A sua média final é {Média}')

# Acrescentei o código da condicional 'if' somente para treino.

if Média >= 6:
   print('Parabéns! Você foi aprovado.')
else:
   print('Você não foi aprovado.')




#5. Faça um CÓDIGO que converta metros para centímetros.

Metro = float(input('Digite o número em metros para a conversão em centímetros: \n'))
print(f'{Metro} metros equivale a {Metro*100} centímetros.')




#6. Faça um CÓDIGO que peça o raio de um círculo, calcule e mostre sua área.

Raio = float(input('Digite a medida do raio em centímetros: \n'))
π = 3.14

print(f'A área do círculo equivale a {Raio*Raio*3.14} centímetros quadrados.')




#7. Faça um CÓDIGO que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.

Lado = float(input('Digite a medida do lado do quadrado em centímetros: \n'))
Área = Lado*Lado

print(f'A área do quadrado solicitado é de {Área} cm^2. Já o seu dobro equivale a {2*Área} cm^2.')




#8. Faça um CÓDIGO que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

Salário = float(input('Digite quantos reais você ganha por hora: \n'))
Mensal = float(input('Quantas horas você trabalha por mês?: \n'))

print(f'O seu salário mensal é de R${Salário*Mensal}. ')




#9. Faça um CÓDIGO que peça um valor e mostre na tela se o valor é positivo ou negativo.
#Obs.: 0 é um número neutro.

valor = float(input('Digite um valor: \n'))

if valor > 0:
    print('Este valor é positivo.')
    

elif valor < 0:
    print('Este valor é negativo.')

else:
    print('0 é um número neutro.')




#10. Faça um CÓDIGO que verifique se uma letra digitada é "F" ou "M". Conforme a letra escrever: F - Feminino, M - Masculino, Sexo Inválido.

nome = input('Digite o seu nome: \n')
sexo = input('Digite m(masculino) ou f(feminino) minúsculo para representar o seu gênero : \n')

if sexo == 'm':
    print(f'{nome} é do sexo Masculino.')
elif sexo == 'f':
    print(f'{nome} é do sexo Feminino.')
else:
    print('Sexo Inválido.')

#Considerações finais:

print('Atividade de LPC finalizada')
# Out:
# Olá ETE PORTO DIGITAL!
# Digite um número:
# 68
# O número informado foi 68.0
# Coloque um número:
# 90
# Coloque outro número:
# 238
# A soma dos dois números é 328.0
# Digite a sua nota do primeiro bimestre:
# 9
# Digite a sua nota do segundo bimestre:
# 7.5
# Digite a sua nota do terceiro bimestre:
# 8
# Digite a sua nota do quarto bimestre:
# 7
# A sua média final é 7.875
# Parabéns! Você foi aprovado.
# Digite o número em metros para a conversão em centímetros:
# 555
# 555.0 metros equivale a 55500.0 centímetros.
# Digite a medida do raio em centímetros:
# 7
# A área do círculo equivale a 153.86 centímetros quadrados.
# Digite a medida do lado do quadrado em centímetros:
# 13
# A área do quadrado solicitado é de 169.0 cm^2. Já o seu dobro equivale a 338.0 cm^2.
# Digite quantos reais você ganha por hora:
# 20
# Quantas horas você trabalha por mês?:
# 130
# O seu salário mensal é de R$2600.0.
# Digite um valor:
# 194
# Este valor é positivo.
# Digite o seu nome:
# ...
